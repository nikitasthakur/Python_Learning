# %%
import pandas as pd
import numpy as np

# %%
perf_data = pd.read_csv('./datasets/StudentsPerformance.csv')

# %%
perf_data.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
gender_filter = perf_data["gender"].isin(['female'])
gender_filter.head(10)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# Name: gender, dtype: bool

# %%
perf_data[gender_filter].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 9   female        group B                 high school  free/reduced
# 12  female        group B                 high school      standard
# 14  female        group A             master's degree      standard
# 15  female        group C            some high school      standard
# 17  female        group B            some high school  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# 1                completed          69             90             88
# ...

# %%
perf_data[~gender_filter].head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 10   male        group C          associate's degree      standard
# 11   male        group D          associate's degree      standard
# 13   male        group A                some college      standard
# 16   male        group C                 high school      standard
# 18   male        group C             master's degree  free/reduced
# 20   male        group D                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 4                     none          76             78             75
# ...

# %%
condition = perf_data["gender"].isin(["female"]) & (perf_data["reading score"] > perf_data["writing score"])
condition.head()
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
perf_data[condition].head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92
# 9                    none          38             60             50

# %%
course_filter = perf_data["test preparation course"].isin(["completed"])
course_filter.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: test preparation course, dtype: bool

# %%
perf_data[course_filter & gender_filter].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1   female        group C                some college      standard
# 6   female        group B                some college      standard
# 21  female        group B                some college  free/reduced
# 38  female        group D          associate's degree  free/reduced
# 46  female        group A          associate's degree      standard
# 48  female        group D          associate's degree  free/reduced
# 54  female        group C            some high school  free/reduced
# 56  female        group E          associate's degree      standard
# 70  female        group D                some college  free/reduced
# 78  female        group D            some high school      standard
#
#    test preparation course  math score  reading score  writing score
# 1                completed          69             90             88
# 6                completed          88             95             92
# ...

# %%
education_levels = ["associate's degree","bachelor's degree"]

# %%
perf_data.filter(items=['gender','test preparation course','math score','reading score']).head(10)
# Out:
#    gender test preparation course  math score  reading score
# 0  female                    none          72             72
# 1  female               completed          69             90
# 2  female                    none          90             95
# 3    male                    none          47             57
# 4    male                    none          76             78
# 5  female                    none          71             83
# 6  female               completed          88             95
# 7    male                    none          40             43
# 8    male               completed          64             64
# 9  female                    none          38             60

# %%
perf_data.filter(regex = 'score',axis = 1).head(10)
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75
# 5          71             83             78
# 6          88             95             92
# 7          40             43             39
# 8          64             64             67
# 9          38             60             50

# %%
perf_data.filter(like = '14',axis = 0).head(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 14   female        group A             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 140  female        group D            some high school      standard
# 141  female        group C                some college  free/reduced
# 142  female        group E                some college  free/reduced
# 143    male        group A                 high school      standard
# 144    male        group D                some college      standard
# 145  female        group C                some college  free/reduced
# 146    male        group B            some high school      standard
# 147    male        group C          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 14                     none          50             53             58
# ...

# %%
groupA  = perf_data['race/ethnicity'] == 'group A'

perf_data[groupA].head(10)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 13    male        group A                some college      standard
# 14  female        group A             master's degree      standard
# 25    male        group A             master's degree  free/reduced
# 46  female        group A          associate's degree      standard
# 61    male        group A            some high school  free/reduced
# 62    male        group A          associate's degree  free/reduced
# 72  female        group A          associate's degree  free/reduced
# 77    male        group A           bachelor's degree      standard
# 82    male        group A                some college  free/reduced
#
#    test preparation course  math score  reading score  writing score
# 3                     none          47             57             44
# 13               completed          78             72             70
# ...
